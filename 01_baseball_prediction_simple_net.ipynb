# %%
weight = 0.1

def natural_network (game, weight):

  prediction =  game * weight
  return prediction

# %%
#среднее количество сыгранных игроками команды игрnumber_of_games = [8.5, 9.5, 10, 9]

game = number_of_games[0]

pred = natural_network(game, weight)

print(pred)
# Out:
# 0.8500000000000001
